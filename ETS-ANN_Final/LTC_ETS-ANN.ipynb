# %% [markdown]
# ## ETS-ANN Hybrid Model based on Panigrahi Algorithm Steps

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import MinMaxScaler
# Use TSForecastExperiment from pycaret.time_series directly
from pycaret.time_series import TSForecastingExperiment, setup, create_model, compare_models, predict_model, get_config
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import mean_absolute_percentage_error, mean_absolute_error, mean_squared_error, r2_score
import yfinance as yf
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Step 1: Given Time Series y

# %%
# Download Litecoin data
df_LTC = yf.download(
    tickers=["LTC-USD"],
    start="2020-01-01",
    end="2025-01-01" # yf downloads up to the day before
)

# Basic Cleaning and Selection
# Rename for clarity
df_LTC.columns = ['Open', 'High', 'Low', 'Close', 'Volume'] 
print(f"Original shape: {df_LTC.shape}")
# Forward fill for potential missing values
df_LTC.ffill(inplace=True)

# Select Target and Set Index
df_LTC.reset_index(inplace=True)
df_LTC['Date'] = pd.to_datetime(df_LTC['Date'], format='%Y-%m-%d')
df_LTC = df_LTC[['Date', 'Close']]
df_LTC.set_index('Date', inplace=True)

# Ensure Daily Frequency
df_LTC = df_LTC.asfreq('D')
# Fill again if necessary
df_LTC.ffill(inplace=True)  
print(f"Shape after preproc: {df_LTC.shape}")
print(f"Frequency of the index: {df_LTC.index.freq}")
print("\nData Head:")
print(df_LTC.head())
# The full time series y_t
y_full = df_LTC['Close']
# Out:
# [*********************100%***********************]  1 of 1 completed
# Original shape: (1827, 5)
# Shape after preproc: (1827, 1)
# Frequency of the index: <Day>
#
# Data Head:
#                 Close
# Date
# 2020-01-01  41.326534
# 2020-01-02  42.018085
# 2020-01-03  39.863129
# 2020-01-04  42.383526
# 2020-01-05  43.291382

# %% [markdown]
# ## Step 2: Define In-Sample (Train+Val) and Out-of-Sample (Test) Splits
# ## Using 60% Train, 20% Validation -> 80% In-Sample; 20% Test

# %%
n_total = len(y_full)
n_train = int(0.6 * n_total)
n_val = int(0.2 * n_total)
n_test = n_total - n_train - n_val
n_insample = n_train + n_val # l_i in Algorithm 1

y_train_data = y_full[:n_train]
y_val_data = y_full[n_train:n_insample]
y_insample_data = y_full[:n_insample] # Data for used in the steps 4-9 (l_i)
y_test_data = y_full[n_insample:]     # Data for final evaluation (l_o)

print(f"Total samples: {n_total}")
print(f"In-Sample (l_i): {n_insample} (Train: {n_train}, Val: {n_val})")
print(f"Out-of-Sample (l_o): {n_test}")
print(f"In-Sample Start: {y_insample_data.index.min()}, End: {y_insample_data.index.max()}")
print(f"Out-of-Sample Start: {y_test_data.index.min()}, End: {y_test_data.index.max()}")

# Define forecast horizon for PyCaret setup (length of test set)
fh_test = n_test
# Out:
# Total samples: 1827
# In-Sample (l_i): 1461 (Train: 1096, Val: 365)
# Out-of-Sample (l_o): 366
# In-Sample Start: 2020-01-01 00:00:00, End: 2023-12-31 00:00:00
# Out-of-Sample Start: 2024-01-01 00:00:00, End: 2024-12-31 00:00:00

# %% [markdown]
# ## Step 3 & 4: Normalize In-Sample (Skipped Adaptation) & Determine Best ETS
# Adaptation: We are focusing on picking the best forecasting model (ETS).Any special adjustments to our initial data will be skipped for now, letting PyCaret handle any necessary scaling behind the scenes. When we set up PyCaret with our entire dataset and tell it how many future periods we want to predict (fh=n_test), it cleverly creates its own internal training set. This internal training data is essentially what we've been calling our 'y_insample_data' – the historical data we'll use to train and find the best ETS model.

# %%
# Setup PyCaret using the FULL data, defining fh=n_test creates the correct internal train/test split
# The internal training data corresponds conceptually to our 'y_insample_data' for fitting purposes
exp_ltc = TSForecastingExperiment()
setup(data=df_LTC, # Use the full DataFrame
      target='Close',
      fh=fh_test,
      session_id=123,
      numeric_imputation_target="ffill"
     )

# Retrieve PyCaret's internal training data for clarity (this is what models fit on)
y_train_pycaret = get_config('y_train')
print(f"\nPyCaret Internal Training Data length: {len(y_train_pycaret)}")
print(f"Matches expected In-Sample length? {len(y_train_pycaret) == n_insample}") # Should be True or very close

print("\n--- Comparing ETS Models (using PyCaret's internal validation) ---")
# compare_models evaluates on PyCaret's internal validation set (hold-out defined by fh)
best_ets_model_obj = compare_models(include=['ets', 'exp_smooth'],
                                    sort='RMSE',
                                    n_select=1)

print(f"\n--- Best ETS Model Selected by PyCaret: ---")
print(best_ets_model_obj)
# Out:
# <style type="text/css">
# #T_3bb36_row23_col1, #T_3bb36_row28_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_3bb36">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3bb36_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_3bb36_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3bb36_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3bb36_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_3bb36_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_3bb36_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3bb36_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_3bb36_row1_col1" class="data row1 col1" >Close</td>
#     </tr>
#     <tr>
#       <th id="T_3bb36_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3bb36_row2_col0" class="data row2 col0" >Approach</td>
#       <td id="T_3bb36_row2_col1" class="data row2 col1" >Univariate</td>
#     </tr>
#     <tr>
#       <th id="T_3bb36_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3bb36_row3_col0" class="data row3 col0" >Exogenous Variables</td>
#       <td id="T_3bb36_row3_col1" class="data row3 col1" >Not Present</td>
#     </tr>
#     <tr>
#       <th id="T_3bb36_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3bb36_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_3bb36_row4_col1" class="data row4 col1" >(1827, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_3bb36_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3bb36_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_3bb36_row5_col1" class="data row5 col1" >(1827, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_3bb36_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3bb36_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_3bb36_row6_col1" class="data row6 col1" >(1461, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_3bb36_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3bb36_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_3bb36_row7_col1" class="data row7 col1" >(366, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_3bb36_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_3bb36_row8_col0" class="data row8 col0" >Rows with missing values</td>
#       <td id="T_3bb36_row8_col1" class="data row8 col1" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_3bb36_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_3bb36_row9_col0" class="data row9 col0" >Fold Generator</td>
#       <td id="T_3bb36_row9_col1" class="data row9 col1" >ExpandingWindowSplitter</td>
#     </tr>
#     <tr>
#       <th id="T_3bb36_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_3bb36_row10_col0" class="data row10 col0" >Fold Number</td>
#       <td id="T_3bb36_row10_col1" class="data row10 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_3bb36_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_3bb36_row11_col0" class="data row11 col0" >Enforce Prediction Interval</td>
#       <td id="T_3bb36_row11_col1" class="data row11 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_3bb36_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_3bb36_row12_col0" class="data row12 col0" >Splits used for hyperparameters</td>
#       <td id="T_3bb36_row12_col1" class="data row12 col1" >all</td>
#     </tr>
#     <tr>
#       <th id="T_3bb36_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_3bb36_row13_col0" class="data row13 col0" >Seasonality Detection Algo</td>
#       <td id="T_3bb36_row13_col1" class="data row13 col1" >auto</td>
#     </tr>
#     <tr>
#       <th id="T_3bb36_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_3bb36_row14_col0" class="data row14 col0" >Max Period to Consider</td>
#       <td id="T_3bb36_row14_col1" class="data row14 col1" >60</td>
#     </tr>
#     <tr>
#       <th id="T_3bb36_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_3bb36_row15_col0" class="data row15 col0" >Seasonal Period(s) Tested</td>
#       <td id="T_3bb36_row15_col1" class="data row15 col1" >[4, 31, 40, 9, 58, 2, 28, 6, 59, 20]</td>
#     </tr>
#     <tr>
#       <th id="T_3bb36_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_3bb36_row16_col0" class="data row16 col0" >Significant Seasonal Period(s)</td>
#       <td id="T_3bb36_row16_col1" class="data row16 col1" >[4, 31, 40, 9, 58, 2, 28, 6, 59, 20]</td>
#     </tr>
#     <tr>
#       <th id="T_3bb36_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_3bb36_row17_col0" class="data row17 col0" >Significant Seasonal Period(s) without Harmonics</td>
#       <td id="T_3bb36_row17_col1" class="data row17 col1" >[40, 31, 9, 58, 28, 6, 59]</td>
#     </tr>
#     <tr>
#       <th id="T_3bb36_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_3bb36_row18_col0" class="data row18 col0" >Remove Harmonics</td>
#       <td id="T_3bb36_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_3bb36_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_3bb36_row19_col0" class="data row19 col0" >Harmonics Order Method</td>
#       <td id="T_3bb36_row19_col1" class="data row19 col1" >harmonic_max</td>
#     </tr>
#     <tr>
#       <th id="T_3bb36_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_3bb36_row20_col0" class="data row20 col0" >Num Seasonalities to Use</td>
#       <td id="T_3bb36_row20_col1" class="data row20 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_3bb36_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_3bb36_row21_col0" class="data row21 col0" >All Seasonalities to Use</td>
#       <td id="T_3bb36_row21_col1" class="data row21 col1" >[4]</td>
#     </tr>
#     <tr>
#       <th id="T_3bb36_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_3bb36_row22_col0" class="data row22 col0" >Primary Seasonality</td>
#       <td id="T_3bb36_row22_col1" class="data row22 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_3bb36_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_3bb36_row23_col0" class="data row23 col0" >Seasonality Present</td>
#       <td id="T_3bb36_row23_col1" class="data row23 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_3bb36_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_3bb36_row24_col0" class="data row24 col0" >Target Strictly Positive</td>
#       <td id="T_3bb36_row24_col1" class="data row24 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_3bb36_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_3bb36_row25_col0" class="data row25 col0" >Target White Noise</td>
#       <td id="T_3bb36_row25_col1" class="data row25 col1" >No</td>
#     </tr>
#     <tr>
#       <th id="T_3bb36_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_3bb36_row26_col0" class="data row26 col0" >Recommended d</td>
#       <td id="T_3bb36_row26_col1" class="data row26 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_3bb36_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_3bb36_row27_col0" class="data row27 col0" >Recommended Seasonal D</td>
#       <td id="T_3bb36_row27_col1" class="data row27 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_3bb36_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_3bb36_row28_col0" class="data row28 col0" >Preprocess</td>
#       <td id="T_3bb36_row28_col1" class="data row28 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_3bb36_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_3bb36_row29_col0" class="data row29 col0" >Numerical Imputation (Target)</td>
#       <td id="T_3bb36_row29_col1" class="data row29 col1" >ffill</td>
# PyCaret Internal Training Data length: 1461
# Matches expected In-Sample length? True
#
# --- Comparing ETS Models (using PyCaret's internal validation) ---
# <style type="text/css">
# #T_72d9d th {
#   text-align: left;
# }
# #T_72d9d_row0_col0, #T_72d9d_row1_col0, #T_72d9d_row1_col1, #T_72d9d_row1_col2, #T_72d9d_row1_col3, #T_72d9d_row1_col4, #T_72d9d_row1_col5, #T_72d9d_row1_col6, #T_72d9d_row1_col7 {
#   text-align: left;
# }
# #T_72d9d_row0_col1, #T_72d9d_row0_col2, #T_72d9d_row0_col3, #T_72d9d_row0_col4, #T_72d9d_row0_col5, #T_72d9d_row0_col6, #T_72d9d_row0_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_72d9d_row0_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# #T_72d9d_row1_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_72d9d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_72d9d_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_72d9d_level0_col1" class="col_heading level0 col1" >MASE</th>
#       <th id="T_72d9d_level0_col2" class="col_heading level0 col2" >RMSSE</th>
#       <th id="T_72d9d_level0_col3" class="col_heading level0 col3" >MAE</th>
#       <th id="T_72d9d_level0_col4" class="col_heading level0 col4" >RMSE</th>
#       <th id="T_72d9d_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_72d9d_level0_col6" class="col_heading level0 col6" >SMAPE</th>
#       <th id="T_72d9d_level0_col7" class="col_heading level0 col7" >R2</th>
#       <th id="T_72d9d_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_72d9d_level0_row0" class="row_heading level0 row0" >exp_smooth</th>
#       <td id="T_72d9d_row0_col0" class="data row0 col0" >Exponential Smoothing</td>
#       <td id="T_72d9d_row0_col1" class="data row0 col1" >6.3450</td>
#       <td id="T_72d9d_row0_col2" class="data row0 col2" >4.9758</td>
#       <td id="T_72d9d_row0_col3" class="data row0 col3" >47.0052</td>
#       <td id="T_72d9d_row0_col4" class="data row0 col4" >56.3131</td>
#       <td id="T_72d9d_row0_col5" class="data row0 col5" >0.5771</td>
#       <td id="T_72d9d_row0_col6" class="data row0 col6" >0.3746</td>
#       <td id="T_72d9d_row0_col7" class="data row0 col7" >-3.5224</td>
#       <td id="T_72d9d_row0_col8" class="data row0 col8" >2.3100</td>
#     </tr>
#     <tr>
#       <th id="T_72d9d_level0_row1" class="row_heading level0 row1" >ets</th>
#       <td id="T_72d9d_row1_col0" class="data row1 col0" >ETS</td>
#       <td id="T_72d9d_row1_col1" class="data row1 col1" >10.1154</td>
#       <td id="T_72d9d_row1_col2" class="data row1 col2" >7.4044</td>
#       <td id="T_72d9d_row1_col3" class="data row1 col3" >64.2365</td>
#       <td id="T_72d9d_row1_col4" class="data row1 col4" >73.7113</td>
#       <td id="T_72d9d_row1_col5" class="data row1 col5" >0.7046</td>
#       <td id="T_72d9d_row1_col6" class="data row1 col6" >0.4372</td>
#       <td id="T_72d9d_row1_col7" class="data row1 col7" >-5.0313</td>
#       <td id="T_72d9d_row1_col8" class="data row1 col8" >3.7933</td>
#     </tr>
#   </tbody>
# </table>
# --- Best ETS Model Selected by PyCaret: ---
# ExponentialSmoothing(seasonal='mul', sp=4, trend='add')

# %% [markdown]
# ## Step 5 & 6: Obtain ETS In-Sample Predictions (Fitted Values) & De-normalize
# ## Adaptation: Get fitted values on ORIGINAL scale directly. No de-normalization needed.

# %%
print("\n--- Obtaining In-Sample ETS Fitted Values ---")
# Use the fitted model object from PyCaret
try:
    # Access fitted values from the underlying statsmodels/sktime object
    # Ensure these correspond to the training data PyCaret used (y_train_pycaret)
    ets_fitted_values_train = best_ets_model_obj._fitted_forecaster.fittedvalues
    # Align index explicitly with PyCaret's training index
    ets_fitted_values_train = ets_fitted_values_train.reindex(y_train_pycaret.index)

except AttributeError:
    print("Warning: Could not directly access fittedvalues. Predicting on training data as fallback.")
    # Predict on the training data PyCaret used
    ets_fitted_values_train = predict_model(best_ets_model_obj, X=get_config('X_train'))['y_pred']
    # Ensure index matches PyCaret's training index
    ets_fitted_values_train = ets_fitted_values_train.reindex(y_train_pycaret.index)

# Check alignment
if not y_train_pycaret.index.equals(ets_fitted_values_train.index):
     print("CRITICAL WARNING: Index mismatch between y_train_pycaret and ETS fitted values after reindex.")
     # Optional: Add more robust alignment or raise error here
else:
     print("Indices between y_train_pycaret and ETS fitted values aligned.")

# Drop any NaNs potentially introduced at the start by the ETS model fitting
ets_fitted_values_train.dropna(inplace=True)
# Align original training data to match the valid fitted values index
y_train_pycaret_aligned = y_train_pycaret.reindex(ets_fitted_values_train.index)

print(f"Number of valid ETS fitted values: {len(ets_fitted_values_train)}")
print("ETS Fitted Values Head:")
print(ets_fitted_values_train.head())

# These fitted values represent Č_t^1 for the in-sample period (t=1 to l_i)
# Out:
# --- Obtaining In-Sample ETS Fitted Values ---
# Indices between y_train_pycaret and ETS fitted values aligned.
# Number of valid ETS fitted values: 1461
# ETS Fitted Values Head:
# Date
# 2020-01-01    47.803660
# 2020-01-02    41.089895
# 2020-01-03    42.557169
# 2020-01-04    40.166616
# 2020-01-05    41.984744
# Freq: D, dtype: float64

# %% [markdown]
# ## Step 7: Obtain Residual Series (In-Sample)
# ## e_t = y_t - Č_t^1 (for t = 1 to l_i)

# %%
print("\n--- Calculating In-Sample Residuals ---")
# Use the aligned PyCaret training data and the valid fitted values
residuals_insample = y_train_pycaret_aligned - ets_fitted_values_train
residuals_insample.dropna(inplace=True) # Should already be handled, but good practice

print(f"Number of valid In-Sample Residuals: {len(residuals_insample)}")
print("Residuals Head:")
print(residuals_insample.head())

plt.figure(figsize=(12, 4))
# >>> FIX: Convert index to timestamp for plotting <<<
plt.plot(residuals_insample.index.to_timestamp(), residuals_insample, label='ETS In-Sample Residuals')
plt.title('Residuals from Best ETS Model Fit (In-Sample Data)')
plt.xlabel('Date')
plt.ylabel('Residual Value')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# --- Calculating In-Sample Residuals ---
# Number of valid In-Sample Residuals: 1461
# Residuals Head:
# Date
# 2020-01-01   -6.477126
# 2020-01-02    0.928191
# 2020-01-03   -2.694041
# 2020-01-04    2.216909
# 2020-01-05    1.306637
# Freq: D, dtype: float64

# %% [markdown]
# ## Step 8 & 9: Perform Lag Selection (Using Fixed Lags) & Normalize Residuals
# ## Normalize the valid in-sample residual series e_t using its own min/max

# %%
# Step 8: Lag Selection (Using predefined lags from your original code)
lags_to_use = [1, 7, 30]
print(f"\nUsing fixed lags for ANN: {lags_to_use}")

# Step 9: Normalize the calculated in-sample residuals
print("\n--- Normalizing In-Sample Residuals ---")
scaler_residuals = MinMaxScaler(feature_range=(-1, 1)) # Scaler for residuals
# Fit scaler ONLY on the valid in-sample residuals
normalized_residuals_insample = scaler_residuals.fit_transform(residuals_insample.values.reshape(-1, 1))

# Convert back to Series with correct index
normalized_residuals_insample_series = pd.Series(normalized_residuals_insample.flatten(), index=residuals_insample.index)

print("Normalized Residuals Head:")
print(normalized_residuals_insample_series.head())
# Out:
# Using fixed lags for ANN: [1, 7, 30]
#
# --- Normalizing In-Sample Residuals ---
# Normalized Residuals Head:
# Date
# 2020-01-01    0.267418
# 2020-01-02    0.361833
# 2020-01-03    0.315651
# 2020-01-04    0.378263
# 2020-01-05    0.366658
# Freq: D, dtype: float64

# %% [markdown]
# ## Step 10a: Prepare Lagged Residual Data for ANN

# %%
# Create lagged features from the NORMALIZED IN-SAMPLE residuals
def create_lagged_features_ann(series, lags):
    lagged_data = pd.DataFrame(index=series.index)
    lagged_data['target'] = series # Target is the normalized residual
    for lag in lags:
        lagged_data[f'lag_{lag}'] = series.shift(lag)
    lagged_data.dropna(inplace=True) # Remove NaNs from shifting
    return lagged_data

lagged_normalized_residuals = create_lagged_features_ann(normalized_residuals_insample_series, lags_to_use)

print("\n--- Lagged Normalized Residual Features Created ---")
print(f"Shape of lagged residual data for ANN: {lagged_normalized_residuals.shape}")
print("Lagged Data Head:")
print(lagged_normalized_residuals.head())

# Separate features (X) and target (y) for ANN training/tuning
X_ann_resid = lagged_normalized_residuals.drop('target', axis=1)
y_ann_resid = lagged_normalized_residuals['target']
# Out:
# --- Lagged Normalized Residual Features Created ---
# Shape of lagged residual data for ANN: (1431, 4)
# Lagged Data Head:
#               target     lag_1     lag_7    lag_30
# Date
# 2020-01-31  0.443504  0.349971  0.298916  0.267418
# 2020-02-01  0.345088  0.443504  0.352874  0.361833
# 2020-02-02  0.393160  0.345088  0.345500  0.315651
# 2020-02-03  0.349681  0.393160  0.373510  0.378263
# 2020-02-04  0.334313  0.349681  0.379022  0.366658

# %% [markdown]
# ## Step 10b: ANN Tuning (Using Validation Split within In-Sample Residuals)

# %%
# Split the valid residual feature data for ANN tuning (e.g., 80% train, 20% validation within this set)
# This conceptually uses the 60% original for train, 20% original for validation
X_ann_train_tune, X_ann_val_tune, y_ann_train_tune, y_ann_val_tune = train_test_split(
    X_ann_resid, y_ann_resid, test_size=0.25, shuffle=False # 0.25 * 0.80 = 0.20 of total
)

print("\n--- Data Split for ANN Tuning (from Residuals) ---")
print(f"ANN Tuning Train shape: {X_ann_train_tune.shape}")
print(f"ANN Tuning Validation shape: {X_ann_val_tune.shape}")

# --- Manual Tuning Loop (Example - same as refined code) ---
neuron_options = [25, 50, 100]
epochs_options = [30, 50]
batch_size_options = [32, 64]

# Split the valid residual feature data for ANN tuning (e.g., 80% train, 20% validation within this set)
# This conceptually uses the 60% original for train, 20% original for validation
X_ann_train_tune, X_ann_val_tune, y_ann_train_tune, y_ann_val_tune = train_test_split(
    X_ann_resid, y_ann_resid, test_size=0.25, shuffle=False # 0.25 * 0.80 = 0.20 of total
)

print("\n--- Data Split for ANN Tuning (from Residuals) ---")
print(f"ANN Tuning Train shape: {X_ann_train_tune.shape}")
print(f"ANN Tuning Validation shape: {X_ann_val_tune.shape}")

# --- Starting ANN Hyperparameter Tuning ---
# ... (neuron_options, epochs_options, batch_size_options defined) ...
best_val_mse = float('inf')
best_params_ann = None
# Removed best_model_ann_tuned storage here as we just need parameters for final training

print("\n--- Starting ANN Hyperparameter Tuning ---")
for neurons in neuron_options:
    for epochs in epochs_options:
        for batch_size in batch_size_options:
            print(f"Trying: Neurons={neurons}, Epochs={epochs}, Batch Size={batch_size}")

            # Build ANN model for this trial
            ann_model_tune = Sequential([
                Dense(neurons, activation='relu', input_shape=(X_ann_train_tune.shape[1],)),
                Dense(max(10, neurons//2), activation='relu'), # Example second layer
                Dense(1) # Linear output for regression
            ])
            ann_model_tune.compile(optimizer=Adam(learning_rate=0.001), loss='mse') # Use a consistent learning rate

            # Train model on tuning training set, validate on tuning validation set
            history = ann_model_tune.fit(X_ann_train_tune.values, y_ann_train_tune.values,
                                         epochs=epochs,
                                         batch_size=batch_size,
                                         validation_data=(X_ann_val_tune.values, y_ann_val_tune.values),
                                         verbose=0) # Set verbose=0 to avoid excessive output during tuning

            # Evaluate on tuning validation set using the recorded history
            # Ensure history.history['val_loss'] is not empty
            if 'val_loss' in history.history and len(history.history['val_loss']) > 0:
                 val_mse = history.history['val_loss'][-1] # Get final validation MSE from the last epoch
                 print(f"  Validation MSE: {val_mse:.6f}")

                 # Update best parameters if current model is better
                 if val_mse < best_val_mse:
                     best_val_mse = val_mse
                     best_params_ann = {'neurons': neurons, 'epochs': epochs, 'batch_size': batch_size}
            else:
                 print("  Warning: No validation loss recorded for this trial.")
                 val_mse = float('inf') # Assign infinite MSE if training failed or val_loss wasn't recorded


print("\n--- ANN Tuning Complete ---")
# Add a check in case no valid runs completed
if best_params_ann is None:
     raise ValueError("ANN Tuning failed. No valid parameters found. Check training logs.")

print(f"Best Hyperparameters found (based on Validation MSE): {best_params_ann}")
print(f"Best Validation MSE: {best_val_mse:.6f}")
# Out:
# --- Data Split for ANN Tuning (from Residuals) ---
# ANN Tuning Train shape: (1073, 3)
# ANN Tuning Validation shape: (358, 3)
#
# --- Data Split for ANN Tuning (from Residuals) ---
# ANN Tuning Train shape: (1073, 3)
# ANN Tuning Validation shape: (358, 3)
#
# --- Starting ANN Hyperparameter Tuning ---
# Trying: Neurons=25, Epochs=30, Batch Size=32
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
#   Validation MSE: 0.001495
# Trying: Neurons=25, Epochs=30, Batch Size=64
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
#   Validation MSE: 0.001686
# Trying: Neurons=25, Epochs=50, Batch Size=32
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
#   Validation MSE: 0.001525
# Trying: Neurons=25, Epochs=50, Batch Size=64
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
#   Validation MSE: 0.001508
# Trying: Neurons=50, Epochs=30, Batch Size=32
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
#   Validation MSE: 0.001462
# Trying: Neurons=50, Epochs=30, Batch Size=64
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
#   Validation MSE: 0.001446
# Trying: Neurons=50, Epochs=50, Batch Size=32
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
#   Validation MSE: 0.001463
# Trying: Neurons=50, Epochs=50, Batch Size=64
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
#   Validation MSE: 0.001482
# Trying: Neurons=100, Epochs=30, Batch Size=32
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
#   Validation MSE: 0.001532
# Trying: Neurons=100, Epochs=30, Batch Size=64
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
#   Validation MSE: 0.001449
# Trying: Neurons=100, Epochs=50, Batch Size=32
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
#   Validation MSE: 0.001524
# Trying: Neurons=100, Epochs=50, Batch Size=64
#   Validation MSE: 0.001765
#
# --- ANN Tuning Complete ---
# Best Hyperparameters found (based on Validation MSE): {'neurons': 50, 'epochs': 30, 'batch_size': 64}
# Best Validation MSE: 0.001446

# %% [markdown]
# ## Step 10c: Train Final ANN on All In-Sample Residual Data

# %%
print("\n--- Training Final ANN on All In-Sample Residual Data ---")

# Build the final model with best hyperparameters
final_ann_model = Sequential([
    Dense(best_params_ann['neurons'], activation='relu', input_shape=(X_ann_resid.shape[1],)),
    Dense(max(10, best_params_ann['neurons']//2), activation='relu'),
    Dense(1) # Linear output
])
final_ann_model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')

# Train on the *entire* lagged residual dataset (X_ann_resid, y_ann_resid)
final_ann_model.fit(X_ann_resid.values, y_ann_resid.values,
                    epochs=best_params_ann['epochs'],
                    batch_size=best_params_ann['batch_size'],
                    verbose=1)

print("\n--- Final ANN Model Training Complete ---")
final_ann_model.summary()
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
# --- Training Final ANN on All In-Sample Residual Data ---
# Epoch 1/30
# 23/23 [==============================] - 1s 3ms/step - loss: 0.0537
# Epoch 2/30
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0113
# Epoch 3/30
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0098
# Epoch 4/30
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0095
# Epoch 5/30
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0093
# Epoch 6/30
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0091
# Epoch 7/30
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0090
# Epoch 8/30
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0089
# Epoch 9/30
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0087
# Epoch 10/30
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0086
# Epoch 11/30
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0084
# Epoch 12/30
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0084
# Epoch 13/30
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0082
# Epoch 14/30
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0082
# Epoch 15/30
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0081
# Epoch 16/30
# 23/23 [==============================] - 0s 19ms/step - loss: 0.0080
# Epoch 17/30
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0080
# Epoch 18/30
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0079
# Epoch 19/30
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0078
# Epoch 20/30
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0077
# Epoch 21/30
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0077
# Epoch 22/30
# 23/23 [==============================] - 0s 10ms/step - loss: 0.0077
# Epoch 23/30
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0077
# Epoch 24/30
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0076
# Epoch 25/30
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0076
# Epoch 26/30
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0076
# Epoch 27/30
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0074
# Epoch 28/30
# 23/23 [==============================] - 0s 9ms/step - loss: 0.0075
# Epoch 29/30
# 23/23 [==============================] - 0s 12ms/step - loss: 0.0075
# Epoch 30/30
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0073
#
# --- Final ANN Model Training Complete ---
# Model: "sequential_25"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_75 (Dense)            (None, 50)                200
#
#  dense_76 (Dense)            (None, 25)                1275
#
#  dense_77 (Dense)            (None, 1)                 26
#
# =================================================================
# Total params: 1,501
# Trainable params: 1,501
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Step 11 (Out-of-Sample): Obtain ANN Predictions & De-normalize
# ## Generate multi-step iterative forecast for residuals (Č_t^2)

# %%
print("\n--- Generating ANN Residual Multi-Step Forecast (Iterative) ---")

# 1. Get last known normalized residuals from the end of the IN-SAMPLE period
last_known_normalized_residuals = normalized_residuals_insample_series.tail(max(lags_to_use)).values

# 2. Initialize forecast list and history
ann_preds_holdout_normalized_list = []
current_history_normalized = list(last_known_normalized_residuals)

# 3. Iterative forecast loop for the length of the test set (n_test or fh_test)
print(f"Forecasting {fh_test} steps ahead...")
for i in range(fh_test):
    input_vector = np.array([current_history_normalized[-lag] for lag in lags_to_use]).reshape(1, -1)
    next_pred_normalized = final_ann_model.predict(input_vector, verbose=0)[0, 0]
    ann_preds_holdout_normalized_list.append(next_pred_normalized)
    current_history_normalized.append(next_pred_normalized)
    current_history_normalized.pop(0)

# 4. Convert predictions to Series with the TEST set index
ann_pred_holdout_normalized = pd.Series(ann_preds_holdout_normalized_list, index=y_test_data.index)

# 5. De-normalize using the scaler fitted on in-sample residuals (scaler_residuals)
ann_pred_holdout_denormalized = scaler_residuals.inverse_transform(ann_pred_holdout_normalized.values.reshape(-1, 1)).flatten()
ann_pred_holdout_denormalized = pd.Series(ann_pred_holdout_denormalized, index=y_test_data.index) # Č_t^2 for out-of-sample

print("\nDe-normalized ANN Residual Predictions (Hold-out) Head:")
print(ann_pred_holdout_denormalized.head())
# Out:
# --- Generating ANN Residual Multi-Step Forecast (Iterative) ---
# Forecasting 366 steps ahead...
#
# De-normalized ANN Residual Predictions (Hold-out) Head:
# Date
# 2024-01-01    0.184227
# 2024-01-02    0.060573
# 2024-01-03    0.055938
# 2024-01-04   -0.114892
# 2024-01-05    0.015639
# Freq: D, dtype: float32

# %% [markdown]
# ## Step 12 (Out-of-Sample): Obtain Final Predictions
# ## Combine ETS predictions (Č_t^1) with ANN predictions (Č_t^2) for out-of-sample period

# %%
print("\n--- Generating ETS Multi-Step Forecast for Hold-Out Period ---")
# Generate ETS forecast Č_t^1 for the out-of-sample period
ets_pred_holdout = predict_model(best_ets_model_obj) # Predicts fh_test steps

# >>> ADD THIS LINE TO CONVERT THE INDEX <<<
ets_pred_holdout.index = ets_pred_holdout.index.to_timestamp()
print(f"ETS Prediction Index Type: {type(ets_pred_holdout.index)}") # Verify it's DatetimeIndex

print("\n--- Combining ETS and ANN Forecasts ---")
# Ensure indices match (PyCaret's predict uses future index, matches y_test_data)
# Also check ANN prediction index type for sanity check
print(f"ANN Prediction Index Type: {type(ann_pred_holdout_denormalized.index)}")

if not ets_pred_holdout.index.equals(ann_pred_holdout_denormalized.index):
     # If error still occurs, print indices to debug further
     print("ETS Index Head:", ets_pred_holdout.index[:5])
     print("ANN Index Head:", ann_pred_holdout_denormalized.index[:5])
     raise ValueError("Index mismatch between ETS and ANN hold-out predictions even after conversion!")

# Final Forecast = ETS Forecast + De-normalized ANN Residual Forecast
final_hybrid_pred_revised = ets_pred_holdout['y_pred'] + ann_pred_holdout_denormalized

print("\nFinal Hybrid Predictions (Hold-out - Revised) Head:")
print(final_hybrid_pred_revised.head())
# Out:
# --- Generating ETS Multi-Step Forecast for Hold-Out Period ---
# <style type="text/css">
# </style>
# <table id="T_4badf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4badf_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_4badf_level0_col1" class="col_heading level0 col1" >MASE</th>
#       <th id="T_4badf_level0_col2" class="col_heading level0 col2" >RMSSE</th>
#       <th id="T_4badf_level0_col3" class="col_heading level0 col3" >MAE</th>
#       <th id="T_4badf_level0_col4" class="col_heading level0 col4" >RMSE</th>
#       <th id="T_4badf_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_4badf_level0_col6" class="col_heading level0 col6" >SMAPE</th>
#       <th id="T_4badf_level0_col7" class="col_heading level0 col7" >R2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4badf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4badf_row0_col0" class="data row0 col0" >Exponential Smoothing</td>
#       <td id="T_4badf_row0_col1" class="data row0 col1" >1.4810</td>
#       <td id="T_4badf_row0_col2" class="data row0 col2" >1.1472</td>
#       <td id="T_4badf_row0_col3" class="data row0 col3" >11.4590</td>
#       <td id="T_4badf_row0_col4" class="data row0 col4" >15.7834</td>
#       <td id="T_4badf_row0_col5" class="data row0 col5" >0.1346</td>
#       <td id="T_4badf_row0_col6" class="data row0 col6" >0.1407</td>
#       <td id="T_4badf_row0_col7" class="data row0 col7" >-0.0320</td>
#     </tr>
#   </tbody>
# </table>
# ETS Prediction Index Type: <class 'pandas.core.indexes.datetimes.DatetimeIndex'>
#
# --- Combining ETS and ANN Forecasts ---
# ANN Prediction Index Type: <class 'pandas.core.indexes.datetimes.DatetimeIndex'>
#
# Final Hybrid Predictions (Hold-out - Revised) Head:
# 2024-01-01    73.384727
# 2024-01-02    73.206373
# 2024-01-03    73.327738
# 2024-01-04    73.238008
# 2024-01-05    73.255339
# Freq: D, dtype: float64

# %% [markdown]
# ## Evaluate Final Hybrid Model Performance

# %%
# Define evaluation metrics function (same as before)
def ts_metrics(y, y_hat, model_name="Model"):
    mae = mean_absolute_error(y, y_hat)
    mape = mean_absolute_percentage_error(y, y_hat)
    rmse = np.sqrt(mean_squared_error(y, y_hat))
    try:
        r2 = r2_score(y, y_hat)
    except ValueError: r2 = np.nan
    print(f"\n--- {model_name} Evaluation Metrics (Hold-out Set) ---")
    print(f"RMSE: {rmse:.4f}, MAE: {mae:.4f}, MAPE: {mape:.4%}, R²: {r2:.4f}")
    return {'MAE': mae, 'MAPE': mape, 'RMSE': rmse, 'R2': r2}

# Evaluate the revised Hybrid model using the original test data split
hybrid_metrics_revised = ts_metrics(y_test_data, final_hybrid_pred_revised, model_name="ETS-ANN Hybrid (Revised)")
# Out:
# --- ETS-ANN Hybrid (Revised) Evaluation Metrics (Hold-out Set) ---
# RMSE: 15.7553, MAE: 11.4709, MAPE: 13.4944%, R²: -0.0283

# %% [markdown]
# ## Visualize Results

# %%
plt.figure(figsize=(14, 7))
plt.plot(y_insample_data.index, y_insample_data, label='Actual Price (In-Sample)', color='blue', alpha=0.6)
plt.plot(y_test_data.index, y_test_data, label='Actual Price (Test)', color='green')
plt.plot(final_hybrid_pred_revised.index, final_hybrid_pred_revised, label='ETS-ANN Hybrid Forecast (Revised)', color='red', linestyle='--')
# plt.plot(ets_pred_holdout.index, ets_pred_holdout['y_pred'], label='ETS Component Forecast', color='orange', linestyle=':', alpha=0.8) # Optional
plt.title('Bitcoin Price Forecasting: Actual vs. ETS-ANN Hybrid (Revised)')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
